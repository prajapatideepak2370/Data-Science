# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
data = np.random.normal(0,100,100)

# %%
#NEGATIVE SKEWED VALUE 
df = pd.DataFrame({"x":data})
df["x"].skew()
# Out:
# np.float64(-0.06377977526977648)

# %%
sns.histplot(x= "x", data=df)
plt.show()
