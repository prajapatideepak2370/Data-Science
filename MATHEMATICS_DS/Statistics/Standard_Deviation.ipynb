# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
Sec_A = np.array([75, 65, 73, 68, 72, 76])
Sec_B = np.array([91, 49, 97, 93, 54, 45])
no = np.array([1, 2, 3, 4, 5, 6])

# %%
mean_A = np.mean(Sec_A)
mean_B = np.mean(Sec_B)
mean_A , mean_B
# Out:
# (np.float64(71.5), np.float64(71.5))

# %% [markdown]
# Standard Deviation

# %%
np.std(Sec_A), np.std(Sec_B)
# Out:
# (np.float64(3.8622100754188224), np.float64(22.38861317723811))

# %% [markdown]
# variance Deviation

# %%
np.var(Sec_A), np.var(Sec_B)
# Out:
# (np.float64(14.916666666666666), np.float64(501.25))
