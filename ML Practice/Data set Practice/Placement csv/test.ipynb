# %%
import numpy as np
import pandas as pd
import os

# %%
df = pd.read_csv('placement.csv')
df.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  100 non-null    int64
#  1   cgpa        100 non-null    float64
#  2   iq          100 non-null    float64
#  3   placement   100 non-null    int64
# dtypes: float64(2), int64(2)
# memory usage: 3.3 KB

# %%
df.shape
# Out:
# (100, 4)

# %%
df = df.iloc[:, 1:]

# %%
df.head()
# Out:
#    cgpa     iq  placement
# 0   6.8  123.0          1
# 1   5.9  106.0          0
# 2   5.3  121.0          0
# 3   7.4  132.0          1
# 4   5.8  142.0          0

# %%
import matplotlib.pylab as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 import matplotlib.pylab as plt
#
# ModuleNotFoundError: No module named 'matplotlib.pylab'

# %%
plt.scatter(df[df['placement']==1]['cgpa'],
            df[df['placement']==1]['iq'],
            color='green',
            label='Yes')

plt.scatter(df[df['placement']==0]['cgpa'],
            df[df['placement']==0]['iq'],
            color='red',
            label='No')

plt.xlabel('CGPA')
plt.ylabel('IQ')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python314\site-packages\matplotlib\font_manager.py:1745, in _get_font(font_filepaths, _kerning_factor, thread_id, enable_last_resort)
#    1744 try:
# -> 1745     last_resort_index = font_filepaths.index((last_resort_path, 0))
#    1746 except ValueError:
#
# ValueError: tuple.index(x): x not in tuple
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python314\site-packages\matplotlib\backend_bases.py:2249, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2246     # we do this instead of `self.figure.draw_without_rendering`
#    2247     # so that we can inject the orientation
#    2248     with getattr(renderer, "_draw_disabled", nullcontext)():
# -> 2249         self.figure.draw(renderer)
#    2250 else:
#    2251     renderer = None
#
# File ~\AppData\Roaming\Python\Python314\site-packages\matplotlib\artist.py:94, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      92 @wraps(draw)
#      93 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 94     result = draw(artist, renderer, *args, **kwargs)
#      95     if renderer._rasterizing:
#      96         renderer.stop_rasterizing()
#
# File ~\AppData\Roaming\Python\Python314\site-packages\matplotlib\artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File ~\AppData\Roaming\Python\Python314\site-packages\matplotlib\figure.py:3282, in Figure.draw(self, renderer)
#    3279             # ValueError can occur when resizing a window.
#    3281     self.patch.draw(renderer)
# -> 3282     mimage._draw_list_compositing_images(
#    3283         renderer, self, artists, self.suppressComposite)
#    3285     renderer.close_group('figure')
#    3286 finally:
#
# File ~\AppData\Roaming\Python\Python314\site-packages\matplotlib\image.py:133, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     131 if not_composite or not has_images:
#     132     for a in artists:
# --> 133         a.draw(renderer)
#     134 else:
#     135     # Composite any adjacent images together
#     136     image_group = []
#
# File ~\AppData\Roaming\Python\Python314\site-packages\matplotlib\artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File ~\AppData\Roaming\Python\Python314\site-packages\matplotlib\axes\_base.py:3350, in _AxesBase.draw(self, renderer)
#    3347 if artists_rasterized:
#    3348     _draw_rasterized(self.get_figure(root=True), artists_rasterized, renderer)
# -> 3350 mimage._draw_list_compositing_images(
#    3351     renderer, self, artists, self.get_figure(root=True).suppressComposite)
#    3353 renderer.close_group('axes')
#    3354 self.stale = False
#
# File ~\AppData\Roaming\Python\Python314\site-packages\matplotlib\image.py:133, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     131 if not_composite or not has_images:
#     132     for a in artists:
# --> 133         a.draw(renderer)
#     134 else:
#     135     # Composite any adjacent images together
#     136     image_group = []
#
# File ~\AppData\Roaming\Python\Python314\site-packages\matplotlib\artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File ~\AppData\Roaming\Python\Python314\site-packages\matplotlib\axis.py:1478, in Axis.draw(self, renderer)
#    1475 renderer.open_group(__name__, gid=self.get_gid())
#    1477 ticks_to_draw = self._update_ticks()
# -> 1478 tlb1, tlb2 = self._get_ticklabel_bboxes(ticks_to_draw, renderer)
#    1480 for tick in ticks_to_draw:
#    1481     tick.draw(renderer)
#
# File ~\AppData\Roaming\Python\Python314\site-packages\matplotlib\axis.py:1404, in Axis._get_ticklabel_bboxes(self, ticks, renderer)
#    1402 def _get_ticklabel_bboxes(self, ticks, renderer):
#    1403     """Return lists of bboxes for ticks' label1's and label2's."""
# -> 1404     return ([tick.label1.get_window_extent(renderer)
#    1405              for tick in ticks
#    1406              if tick.label1.get_visible() and tick.label1.get_in_layout()],
#    1407             [tick.label2.get_window_extent(renderer)
#    1408              for tick in ticks
#    1409              if tick.label2.get_visible() and tick.label2.get_in_layout()])
#
# File ~\AppData\Roaming\Python\Python314\site-packages\matplotlib\text.py:1076, in Text.get_window_extent(self, renderer, dpi)
#    1071     raise RuntimeError(
#    1072         "Cannot get window extent of text w/o renderer. You likely "
#    1073         "want to call 'figure.draw_without_rendering()' first.")
#    1075 with cbook._setattr_cm(fig, dpi=dpi):
# -> 1076     bbox, _, _ = self._get_layout(self._renderer)
#    1077     x, y = self.get_unitless_position()
#    1078     x, y = self.get_transform().transform((x, y))
#
# File ~\AppData\Roaming\Python\Python314\site-packages\matplotlib\text.py:446, in Text._get_layout(self, renderer)
#     443     min_ascent, min_descent, line_gap = renderer._get_font_height_metrics(
#     444         self._fontproperties)
#     445 if min_ascent is None:
# --> 446     font = get_font(fontManager._find_fonts_by_props(self._fontproperties))
#     447     possible = [
#     448         ('OS/2', 'sTypoLineGap', 'sTypoAscender', 'sTypoDescender'),
#     449         ('hhea', 'lineGap', 'ascent', 'descent')
#     450     ]
#     451     for table_name, linegap_key, ascent_key, descent_key in possible:
#
#     [... skipping hidden 1 frame]
#
# File ~\AppData\Roaming\Python\Python314\site-packages\matplotlib\font_manager.py:1820, in get_font(font_filepaths, hinting_factor)
#    1814     case _:
#    1815         paths = tuple(
#    1816             (_cached_realpath(fname.path), fname.face_index)
#    1817             if isinstance(fname, FontPath) else (_cached_realpath(fname), 0)
#    1818             for fname in font_filepaths)
# -> 1820 font = _get_font(
#    1821     # must be a tuple to be cached
#    1822     paths,
#    1823     _kerning_factor=mpl.rcParams['text.kerning_factor'],
#    1824     # also key on the thread ID to prevent segfaults with multi-threading
#    1825     thread_id=threading.get_ident(),
#    1826     enable_last_resort=mpl.rcParams['font.enable_last_resort'],
#    1827 )
#    1828 # Ensure the transform is always consistent.
#    1829 font._set_transform([[0x10000, 0], [0, 0x10000]], [0, 0])
#
# File ~\AppData\Roaming\Python\Python314\site-packages\matplotlib\font_manager.py:1752, in _get_font(font_filepaths, _kerning_factor, thread_id, enable_last_resort)
#    1748     # Add Last Resort font so we always have glyphs regardless of font, unless we're
#    1749     # already in the list.
#    1750     if enable_last_resort:
#    1751         fallback_list.append(
# -> 1752             ft2font.FT2Font(last_resort_path,
#    1753                             _kerning_factor=_kerning_factor,
#    1754                             _warn_if_used=True))
#    1755         last_resort_index = len(fallback_list)
#    1756 font = ft2font.FT2Font(
#    1757     first_fontpath, face_index=first_fontindex,
#    1758     _fallback_list=fallback_list,
#    1759     _kerning_factor=_kerning_factor
#    1760 )
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\praja\\AppData\\Roaming\\Python\\Python314\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\LastResortHE-Regular.ttf'

# %%
X = df.iloc[:, 0:2]
Y = df.iloc[:,-1]
print(X)
print("Shape of X: ",X.shape)
print(Y)
print("Shape of Y: ",Y.shape)
# Out:
#     cgpa     iq
# 0    6.8  123.0
# 1    5.9  106.0
# 2    5.3  121.0
# 3    7.4  132.0
# 4    5.8  142.0
# ..   ...    ...
# 95   4.3  200.0
# 96   4.4   42.0
# 97   6.7  182.0
# 98   6.3  103.0
# 99   6.2  113.0
#
# [100 rows x 2 columns]
# Shape of X:  (100, 2)
# 0     1
# 1     0
# 2     0
# 3     1
# 4     0
#      ..
# 95    0
# 96    0
# 97    1
# 98    1
# 99    1
# Name: placement, Length: 100, dtype: int64
# Shape of Y:  (100,)

# %% [markdown]
# # Train test split

# %%
from sklearn.model_selection import train_test_split

X_train, X_text, Y_train, Y_text = train_test_split(X,Y,test_size=0.1)

# %%
X_train
# Out:
#     cgpa     iq
# 90   7.3   86.0
# 38   6.5  160.0
# 3    7.4  132.0
# 60   6.9  139.0
# 27   6.0  124.0
# ..   ...    ...
# 76   4.9  155.0
# 0    6.8  123.0
# 57   6.5  130.0
# 62   6.0  102.0
# 34   4.8  163.0
#
# [90 rows x 2 columns]

# %%
X_text
# Out:
#     cgpa     iq
# 66   6.9   96.0
# 64   7.0   64.0
# 74   6.7  154.0
# 72   7.3  116.0
# 30   7.6  128.0
# 26   7.0  199.0
# 84   5.7  169.0
# 81   5.4  107.0
# 52   7.0  175.0
# 16   5.2  224.0

# %%
Y_train
# Out:
# 90    1
# 38    1
# 3     1
# 60    1
# 27    1
#      ..
# 76    0
# 0     1
# 57    1
# 62    0
# 34    0
# Name: placement, Length: 90, dtype: int64

# %%
Y_text
# Out:
# 66    1
# 64    1
# 74    1
# 72    1
# 30    1
# 26    1
# 84    0
# 81    0
# 52    1
# 16    0
# Name: placement, dtype: int64

# %% [markdown]
# # Scale the Test Splits

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train = scaler.fit_transform(X_train)

# %%
X_train
# Out:
# array([[ 1.19353459, -0.92623621],
#        [ 0.49883378,  1.00996378],
#        [ 1.28037219,  0.27734757],
#        [ 0.84618418,  0.46050162],
#        [ 0.06464577,  0.06802865],
#        [ 1.01985939,  0.77448   ],
#        [ 0.93302178,  0.46050162],
#        [-0.97740545,  0.51283135],
#        [-0.89056785, -1.58035783],
#        [ 0.41199618,  0.51283135],
#        [-1.41159345,  2.05655837],
#        [-0.45637984,  0.35584216],
#        [-1.75894386, -0.32444432],
#        [ 0.41199618, -0.14129027],
#        [-0.89056785, -0.03663081],
#        [ 1.01985939, -1.92050107],
#        [ 0.75934658,  0.51283135],
#        [ 0.06464577, -1.99899567],
#        [ 1.8882354 ,  0.72215027],
#        [ 1.36720979,  0.95763405],
#        [-0.97740545,  1.24544756],
#        [-0.63005504,  1.03612864],
#        [-1.67210626, -0.55992811],
#        [ 0.67250898,  1.5855908 ],
#        [-2.27996947,  1.61175567],
#        [-0.63005504,  0.27734757],
#        [-0.63005504, -0.29827946],
#        [ 0.75934658, -0.24594973],
#        [-0.71689264, -1.44953351],
#        [-0.54321744, -0.01046595],
#        [ 0.58567138, -0.03663081],
#        [-1.06424305, -0.01046595],
#        [-1.67210626, -1.21404972],
#        [-1.06424305, -0.90007135],
#        [-1.06424305, -1.81584161],
#        [-0.71689264,  1.42860162],
#        [ 1.45404739, -0.84774162],
#        [ 0.23832097, -0.21978486],
#        [-0.10902943,  0.53899621],
#        [ 0.15148337, -0.48143351],
#        [-2.10629427,  2.91999891],
#        [ 0.06464577, -1.44953351],
#        [-0.02219183, -0.40293892],
#        [-0.19586703,  0.27734757],
#        [-0.71689264,  0.17268811],
#        [-1.32475585, -2.07749026],
#        [-0.89056785,  1.95189891],
#        [ 1.36720979,  0.22501784],
#        [-0.54321744, -0.19362   ],
#        [ 1.8013978 , -1.10939027],
#        [-0.45637984,  0.46050162],
#        [ 2.23558581, -0.03663081],
#        [ 0.49883378, -0.82157675],
#        [-0.80373024, -1.5280281 ],
#        [ 0.15148337, -1.05706054],
#        [ 0.58567138,  0.43433676],
#        [ 1.8882354 ,  1.16695297],
#        [ 0.84618418,  0.43433676],
#        [ 1.19353459,  0.40817189],
#        [-0.10902943,  1.16695297],
#        [-0.45637984, -0.19362   ],
#        [-0.19586703,  0.48666648],
#        [ 0.15148337,  0.27734757],
#        [-0.89056785,  0.77448   ],
#        [ 0.32515857,  0.14652324],
#        [ 1.6277226 , -0.19362   ],
#        [-0.89056785,  0.3296773 ],
#        [ 0.06464577,  0.72215027],
#        [-0.97740545, -0.24594973],
#        [ 2.0619106 ,  1.2192827 ],
#        [ 0.15148337,  0.90530432],
#        [ 0.75934658, -0.82157675],
#        [ 0.93302178, -0.24594973],
#        [ 0.32515857,  0.17268811],
#        [ 1.36720979, -1.58035783],
#        [-1.15108065,  0.64365567],
#        [ 0.15148337, -1.47569837],
#        [ 0.32515857, -0.48143351],
#        [-1.32475585,  0.72215027],
#        [-0.19586703,  0.56516108],
#        [-0.63005504, -0.82157675],
#        [-0.80373024, -0.79541189],
#        [ 1.19353459, -1.86817134],
#        [-0.80373024, -0.08896054],
#        [ 0.49883378, -2.20831459],
#        [-0.89056785,  0.87913946],
#        [ 0.75934658,  0.04186378],
#        [ 0.49883378,  0.22501784],
#        [ 0.06464577, -0.50759838],
#        [-0.97740545,  1.08845837]])

# %%
X_text = scaler.fit_transform(X_text)
X_text
# Out:
# array([[ 0.40393223, -1.00136735],
#        [ 0.53016106, -1.68026047],
#        [ 0.15147459,  0.22912643],
#        [ 0.90884753, -0.57705915],
#        [ 1.28753399, -0.32247423],
#        [ 0.53016106,  1.18381988],
#        [-1.11081364,  0.54735758],
#        [-1.48950011, -0.76799784],
#        [ 0.53016106,  0.67465004],
#        [-1.74195776,  1.71420512]])

# %% [markdown]
# # Model Training

# %%
from sklearn.linear_model import LogisticRegression

clf = LogisticRegression()

clf.fit(X_train, Y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 5
#       1 from sklearn.linear_model import LogisticRegression
#       2
#       3 clf = LogisticRegression()
#       4
# ----> 5 clf.fit(X_train, Y_train)
#
# NameError: name 'X_train' is not defined

# %%
clf.predict(X_text)
# Out:
# array([1, 1, 1, 1, 1, 1, 0, 0, 1, 0])

# %%
Y_text
# Out:
# 66    1
# 64    1
# 74    1
# 72    1
# 30    1
# 26    1
# 84    0
# 81    0
# 52    1
# 16    0
# Name: placement, dtype: int64

# %%
Y_pred = clf.predict(X_text)
Y_pred
# Out:
# array([1, 1, 1, 1, 1, 1, 0, 0, 1, 0])

# %%
# Accuracy Score

from sklearn.metrics import accuracy_score

accuracy_score(Y_text, Y_pred)
# Out:
# 1.0

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(X_train, Y_train.values, clf=clf, legend=2)
# Out:
# <Axes: >
# Error in callback <function _draw_all_if_interactive at 0x000001AED3DC4CA0> (for post_execute), with arguments args (),kwargs {}:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python314\site-packages\matplotlib\font_manager.py:1745, in _get_font(font_filepaths, _kerning_factor, thread_id, enable_last_resort)
#    1744 try:
# -> 1745     last_resort_index = font_filepaths.index((last_resort_path, 0))
#    1746 except ValueError:
#
# ValueError: tuple.index(x): x not in tuple
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python314\site-packages\matplotlib\pyplot.py:300, in _draw_all_if_interactive()
#     298 def _draw_all_if_interactive() -> None:
#     299     if matplotlib.is_interactive():
# --> 300         draw_all()
#
# File ~\AppData\Roaming\Python\Python314\site-packages\matplotlib\_pylab_helpers.py:133, in Gcf.draw_all(cls, force)
#     131 for manager in cls.get_all_fig_managers():
#     132     if force or manager.canvas.figure.stale:
# --> 133         manager.canvas.draw_idle()
#
# File ~\AppData\Roaming\Python\Python314\site-packages\matplotlib\backend_bases.py:1989, in FigureCanvasBase.draw_idle(self, *args, **kwargs)
#    1987 if not self._is_idle_drawing:
#    1988     with self._idle_draw_cntx():
# -> 1989         self.draw(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python314\site-packages\matplotlib\backends\backend_agg.py:438, in FigureCanvasAgg.draw(self)
#     435 # Acquire a lock on the shared font cache.
#     436 with (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     437       else nullcontext()):
# --> 438     self.figure.draw(self.renderer)
#     439     # A GUI class may be need to update a window using this draw, so
#     440     # don't forget to call the superclass.
#     441     super().draw()
#
# File ~\AppData\Roaming\Python\Python314\site-packages\matplotlib\artist.py:94, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      92 @wraps(draw)
#      93 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 94     result = draw(artist, renderer, *args, **kwargs)
#      95     if renderer._rasterizing:
#      96         renderer.stop_rasterizing()
#
# File ~\AppData\Roaming\Python\Python314\site-packages\matplotlib\artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File ~\AppData\Roaming\Python\Python314\site-packages\matplotlib\figure.py:3282, in Figure.draw(self, renderer)
#    3279             # ValueError can occur when resizing a window.
#    3281     self.patch.draw(renderer)
# -> 3282     mimage._draw_list_compositing_images(
#    3283         renderer, self, artists, self.suppressComposite)
#    3285     renderer.close_group('figure')
#    3286 finally:
#
# File ~\AppData\Roaming\Python\Python314\site-packages\matplotlib\image.py:133, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     131 if not_composite or not has_images:
#     132     for a in artists:
# --> 133         a.draw(renderer)
#     134 else:
#     135     # Composite any adjacent images together
#     136     image_group = []
#
# File ~\AppData\Roaming\Python\Python314\site-packages\matplotlib\artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File ~\AppData\Roaming\Python\Python314\site-packages\matplotlib\axes\_base.py:3350, in _AxesBase.draw(self, renderer)
#    3347 if artists_rasterized:
#    3348     _draw_rasterized(self.get_figure(root=True), artists_rasterized, renderer)
# -> 3350 mimage._draw_list_compositing_images(
#    3351     renderer, self, artists, self.get_figure(root=True).suppressComposite)
#    3353 renderer.close_group('axes')
#    3354 self.stale = False
#
# File ~\AppData\Roaming\Python\Python314\site-packages\matplotlib\image.py:133, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     131 if not_composite or not has_images:
#     132     for a in artists:
# --> 133         a.draw(renderer)
#     134 else:
#     135     # Composite any adjacent images together
#     136     image_group = []
#
# File ~\AppData\Roaming\Python\Python314\site-packages\matplotlib\artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File ~\AppData\Roaming\Python\Python314\site-packages\matplotlib\axis.py:1478, in Axis.draw(self, renderer)
#    1475 renderer.open_group(__name__, gid=self.get_gid())
#    1477 ticks_to_draw = self._update_ticks()
# -> 1478 tlb1, tlb2 = self._get_ticklabel_bboxes(ticks_to_draw, renderer)
#    1480 for tick in ticks_to_draw:
#    1481     tick.draw(renderer)
#
# File ~\AppData\Roaming\Python\Python314\site-packages\matplotlib\axis.py:1404, in Axis._get_ticklabel_bboxes(self, ticks, renderer)
#    1402 def _get_ticklabel_bboxes(self, ticks, renderer):
#    1403     """Return lists of bboxes for ticks' label1's and label2's."""
# -> 1404     return ([tick.label1.get_window_extent(renderer)
#    1405              for tick in ticks
#    1406              if tick.label1.get_visible() and tick.label1.get_in_layout()],
#    1407             [tick.label2.get_window_extent(renderer)
#    1408              for tick in ticks
#    1409              if tick.label2.get_visible() and tick.label2.get_in_layout()])
#
# File ~\AppData\Roaming\Python\Python314\site-packages\matplotlib\text.py:1076, in Text.get_window_extent(self, renderer, dpi)
#    1071     raise RuntimeError(
#    1072         "Cannot get window extent of text w/o renderer. You likely "
#    1073         "want to call 'figure.draw_without_rendering()' first.")
#    1075 with cbook._setattr_cm(fig, dpi=dpi):
# -> 1076     bbox, _, _ = self._get_layout(self._renderer)
#    1077     x, y = self.get_unitless_position()
#    1078     x, y = self.get_transform().transform((x, y))
#
# File ~\AppData\Roaming\Python\Python314\site-packages\matplotlib\text.py:446, in Text._get_layout(self, renderer)
#     443     min_ascent, min_descent, line_gap = renderer._get_font_height_metrics(
#     444         self._fontproperties)
#     445 if min_ascent is None:
# --> 446     font = get_font(fontManager._find_fonts_by_props(self._fontproperties))
#     447     possible = [
#     448         ('OS/2', 'sTypoLineGap', 'sTypoAscender', 'sTypoDescender'),
#     449         ('hhea', 'lineGap', 'ascent', 'descent')
#     450     ]
#     451     for table_name, linegap_key, ascent_key, descent_key in possible:
#
#     [... skipping hidden 1 frame]
#
# File ~\AppData\Roaming\Python\Python314\site-packages\matplotlib\font_manager.py:1820, in get_font(font_filepaths, hinting_factor)
#    1814     case _:
#    1815         paths = tuple(
#    1816             (_cached_realpath(fname.path), fname.face_index)
#    1817             if isinstance(fname, FontPath) else (_cached_realpath(fname), 0)
#    1818             for fname in font_filepaths)
# -> 1820 font = _get_font(
#    1821     # must be a tuple to be cached
#    1822     paths,
#    1823     _kerning_factor=mpl.rcParams['text.kerning_factor'],
#    1824     # also key on the thread ID to prevent segfaults with multi-threading
#    1825     thread_id=threading.get_ident(),
#    1826     enable_last_resort=mpl.rcParams['font.enable_last_resort'],
#    1827 )
#    1828 # Ensure the transform is always consistent.
#    1829 font._set_transform([[0x10000, 0], [0, 0x10000]], [0, 0])
#
# File ~\AppData\Roaming\Python\Python314\site-packages\matplotlib\font_manager.py:1752, in _get_font(font_filepaths, _kerning_factor, thread_id, enable_last_resort)
#    1748     # Add Last Resort font so we always have glyphs regardless of font, unless we're
#    1749     # already in the list.
#    1750     if enable_last_resort:
#    1751         fallback_list.append(
# -> 1752             ft2font.FT2Font(last_resort_path,
#    1753                             _kerning_factor=_kerning_factor,
#    1754                             _warn_if_used=True))
#    1755         last_resort_index = len(fallback_list)
#    1756 font = ft2font.FT2Font(
#    1757     first_fontpath, face_index=first_fontindex,
#    1758     _fallback_list=fallback_list,
#    1759     _kerning_factor=_kerning_factor
#    1760 )
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\praja\\AppData\\Roaming\\Python\\Python314\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\LastResortHE-Regular.ttf'
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python314\site-packages\matplotlib\font_manager.py:1745, in _get_font(font_filepaths, _kerning_factor, thread_id, enable_last_resort)
#    1744 try:
# -> 1745     last_resort_index = font_filepaths.index((last_resort_path, 0))
#    1746 except ValueError:
#
# ValueError: tuple.index(x): x not in tuple
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python314\site-packages\matplotlib\backend_bases.py:2249, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2246     # we do this instead of `self.figure.draw_without_rendering`
#    2247     # so that we can inject the orientation
#    2248     with getattr(renderer, "_draw_disabled", nullcontext)():
# -> 2249         self.figure.draw(renderer)
#    2250 else:
#    2251     renderer = None
#
# File ~\AppData\Roaming\Python\Python314\site-packages\matplotlib\artist.py:94, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      92 @wraps(draw)
#      93 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 94     result = draw(artist, renderer, *args, **kwargs)
#      95     if renderer._rasterizing:
#      96         renderer.stop_rasterizing()
#
# File ~\AppData\Roaming\Python\Python314\site-packages\matplotlib\artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File ~\AppData\Roaming\Python\Python314\site-packages\matplotlib\figure.py:3282, in Figure.draw(self, renderer)
#    3279             # ValueError can occur when resizing a window.
#    3281     self.patch.draw(renderer)
# -> 3282     mimage._draw_list_compositing_images(
#    3283         renderer, self, artists, self.suppressComposite)
#    3285     renderer.close_group('figure')
#    3286 finally:
#
# File ~\AppData\Roaming\Python\Python314\site-packages\matplotlib\image.py:133, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     131 if not_composite or not has_images:
#     132     for a in artists:
# --> 133         a.draw(renderer)
#     134 else:
#     135     # Composite any adjacent images together
#     136     image_group = []
#
# File ~\AppData\Roaming\Python\Python314\site-packages\matplotlib\artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File ~\AppData\Roaming\Python\Python314\site-packages\matplotlib\axes\_base.py:3350, in _AxesBase.draw(self, renderer)
#    3347 if artists_rasterized:
#    3348     _draw_rasterized(self.get_figure(root=True), artists_rasterized, renderer)
# -> 3350 mimage._draw_list_compositing_images(
#    3351     renderer, self, artists, self.get_figure(root=True).suppressComposite)
#    3353 renderer.close_group('axes')
#    3354 self.stale = False
#
# File ~\AppData\Roaming\Python\Python314\site-packages\matplotlib\image.py:133, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     131 if not_composite or not has_images:
#     132     for a in artists:
# --> 133         a.draw(renderer)
#     134 else:
#     135     # Composite any adjacent images together
#     136     image_group = []
#
# File ~\AppData\Roaming\Python\Python314\site-packages\matplotlib\artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File ~\AppData\Roaming\Python\Python314\site-packages\matplotlib\axis.py:1478, in Axis.draw(self, renderer)
#    1475 renderer.open_group(__name__, gid=self.get_gid())
#    1477 ticks_to_draw = self._update_ticks()
# -> 1478 tlb1, tlb2 = self._get_ticklabel_bboxes(ticks_to_draw, renderer)
#    1480 for tick in ticks_to_draw:
#    1481     tick.draw(renderer)
#
# File ~\AppData\Roaming\Python\Python314\site-packages\matplotlib\axis.py:1404, in Axis._get_ticklabel_bboxes(self, ticks, renderer)
#    1402 def _get_ticklabel_bboxes(self, ticks, renderer):
#    1403     """Return lists of bboxes for ticks' label1's and label2's."""
# -> 1404     return ([tick.label1.get_window_extent(renderer)
#    1405              for tick in ticks
#    1406              if tick.label1.get_visible() and tick.label1.get_in_layout()],
#    1407             [tick.label2.get_window_extent(renderer)
#    1408              for tick in ticks
#    1409              if tick.label2.get_visible() and tick.label2.get_in_layout()])
#
# File ~\AppData\Roaming\Python\Python314\site-packages\matplotlib\text.py:1076, in Text.get_window_extent(self, renderer, dpi)
#    1071     raise RuntimeError(
#    1072         "Cannot get window extent of text w/o renderer. You likely "
#    1073         "want to call 'figure.draw_without_rendering()' first.")
#    1075 with cbook._setattr_cm(fig, dpi=dpi):
# -> 1076     bbox, _, _ = self._get_layout(self._renderer)
#    1077     x, y = self.get_unitless_position()
#    1078     x, y = self.get_transform().transform((x, y))
#
# File ~\AppData\Roaming\Python\Python314\site-packages\matplotlib\text.py:446, in Text._get_layout(self, renderer)
#     443     min_ascent, min_descent, line_gap = renderer._get_font_height_metrics(
#     444         self._fontproperties)
#     445 if min_ascent is None:
# --> 446     font = get_font(fontManager._find_fonts_by_props(self._fontproperties))
#     447     possible = [
#     448         ('OS/2', 'sTypoLineGap', 'sTypoAscender', 'sTypoDescender'),
#     449         ('hhea', 'lineGap', 'ascent', 'descent')
#     450     ]
#     451     for table_name, linegap_key, ascent_key, descent_key in possible:
#
#     [... skipping hidden 1 frame]
#
# File ~\AppData\Roaming\Python\Python314\site-packages\matplotlib\font_manager.py:1820, in get_font(font_filepaths, hinting_factor)
#    1814     case _:
#    1815         paths = tuple(
#    1816             (_cached_realpath(fname.path), fname.face_index)
#    1817             if isinstance(fname, FontPath) else (_cached_realpath(fname), 0)
#    1818             for fname in font_filepaths)
# -> 1820 font = _get_font(
#    1821     # must be a tuple to be cached
#    1822     paths,
#    1823     _kerning_factor=mpl.rcParams['text.kerning_factor'],
#    1824     # also key on the thread ID to prevent segfaults with multi-threading
#    1825     thread_id=threading.get_ident(),
#    1826     enable_last_resort=mpl.rcParams['font.enable_last_resort'],
#    1827 )
#    1828 # Ensure the transform is always consistent.
#    1829 font._set_transform([[0x10000, 0], [0, 0x10000]], [0, 0])
#
# File ~\AppData\Roaming\Python\Python314\site-packages\matplotlib\font_manager.py:1752, in _get_font(font_filepaths, _kerning_factor, thread_id, enable_last_resort)
#    1748     # Add Last Resort font so we always have glyphs regardless of font, unless we're
#    1749     # already in the list.
#    1750     if enable_last_resort:
#    1751         fallback_list.append(
# -> 1752             ft2font.FT2Font(last_resort_path,
#    1753                             _kerning_factor=_kerning_factor,
#    1754                             _warn_if_used=True))
#    1755         last_resort_index = len(fallback_list)
#    1756 font = ft2font.FT2Font(
#    1757     first_fontpath, face_index=first_fontindex,
#    1758     _fallback_list=fallback_list,
#    1759     _kerning_factor=_kerning_factor
#    1760 )
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\praja\\AppData\\Roaming\\Python\\Python314\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\LastResortHE-Regular.ttf'

# %%
import pickle

# %%
pickle.dump(clf,open('model.pkl', 'wb'))
